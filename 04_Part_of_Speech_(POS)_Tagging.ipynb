# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu8410/NLP/blob/main/04_Part_of_Speech_(POS)_Tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)

print("POS Tagging setup completed!")
# Out:
# POS Tagging setup completed!

# %%
sentence = "Dev is studying Natural Language Processing at NIET."

# Tokenization
words = word_tokenize(sentence)

# POS Tagging
pos_tags = nltk.pos_tag(words)

print("========== POS TAGGING ==========")

for word, tag in pos_tags:
    print(f"{word} -> {tag}")
# Out:
# ========== POS TAGGING ==========
# Dev -> NNP
# is -> VBZ
# studying -> VBG
# Natural -> NNP
# Language -> NNP
# Processing -> NNP
# at -> IN
# NIET -> NNP
# . -> .
