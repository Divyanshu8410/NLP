# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu8410/NLP/blob/main/02_Stemming_and_Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
nltk.download('punkt_tab', quiet=True)

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print("Stemming and Lemmatization setup completed!")
# Out:
# Stemming and Lemmatization setup completed!

# %%
text = "The students are studying and playing games. They studied yesterday and played football."

words = nltk.word_tokenize(text)

print("========== ORIGINAL WORDS ==========")
print(words)

print("\n========== STEMMING ==========")
for word in words:
    if word.isalpha():
        print(f"{word} -> {stemmer.stem(word)}")

print("\n========== LEMMATIZATION ==========")
for word in words:
    if word.isalpha():
        print(f"{word} -> {lemmatizer.lemmatize(word)}")
# Out:
# ========== ORIGINAL WORDS ==========
# ['The', 'students', 'are', 'studying', 'and', 'playing', 'games', '.', 'They', 'studied', 'yesterday', 'and', 'played', 'football', '.']
#
# ========== STEMMING ==========
# The -> the
# students -> student
# are -> are
# studying -> studi
# and -> and
# playing -> play
# games -> game
# They -> they
# studied -> studi
# yesterday -> yesterday
# and -> and
# played -> play
# football -> footbal
#
# ========== LEMMATIZATION ==========
# The -> The
# students -> student
# are -> are
# studying -> studying
# and -> and
# playing -> playing
# games -> game
# They -> They
# studied -> studied
# yesterday -> yesterday
# and -> and
# played -> played
# football -> football
