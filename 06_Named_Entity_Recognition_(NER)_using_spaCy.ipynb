# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu8410/NLP/blob/main/06_Named_Entity_Recognition_(NER)_using_spaCy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

print("NER setup completed!")
# Out:
# NER setup completed!

# %%
text = """
Dev is studying Computer Science at NIET in Greater Noida.
He plans to work at Google after graduation.
Google was founded by Larry Page and Sergey Brin.
"""

doc = nlp(text)

print("========== NAMED ENTITY RECOGNITION ==========")

for entity in doc.ents:
    print(f"{entity.text} -> {entity.label_} -> {spacy.explain(entity.label_)}")
# Out:
# ========== NAMED ENTITY RECOGNITION ==========
# Computer Science at -> WORK_OF_ART -> Titles of books, songs, etc.
# NIET -> ORG -> Companies, agencies, institutions, etc.
# Greater Noida -> GPE -> Countries, cities, states
# Google -> ORG -> Companies, agencies, institutions, etc.
# Google -> ORG -> Companies, agencies, institutions, etc.
# Larry Page -> PERSON -> People, including fictional
# Sergey Brin -> PERSON -> People, including fictional
