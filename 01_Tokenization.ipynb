# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshu8410/NLP/blob/main/01_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import spacy

from nltk.tokenize import word_tokenize, sent_tokenize

# Download required NLTK data silently
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

print("NLP libraries loaded successfully!")
# Out:
# NLP libraries loaded successfully!

# %%
text = """Natural Language Processing is a branch of Artificial Intelligence.
It helps computers understand human language.
NLTK and spaCy are popular NLP libraries."""

# ---------- NLTK ----------
print("========== NLTK TOKENIZATION ==========")

print("\nSentence Tokenization:")
sentences = sent_tokenize(text)
for i, sentence in enumerate(sentences, 1):
    print(f"{i}. {sentence}")

print("\nWord Tokenization:")
words = word_tokenize(text)
print(words)


# ---------- spaCy ----------
print("\n========== SPACY TOKENIZATION ==========")

doc = nlp(text)

print("\nSentence Tokenization:")
for i, sent in enumerate(doc.sents, 1):
    print(f"{i}. {sent.text}")

print("\nWord Tokenization:")
print([token.text for token in doc])
# Out:
# ========== NLTK TOKENIZATION ==========
#
# Sentence Tokenization:
# 1. Natural Language Processing is a branch of Artificial Intelligence.
# 2. It helps computers understand human language.
# 3. NLTK and spaCy are popular NLP libraries.
#
# Word Tokenization:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'NLTK', 'and', 'spaCy', 'are', 'popular', 'NLP', 'libraries', '.']
#
# ========== SPACY TOKENIZATION ==========
#
# Sentence Tokenization:
# 1. Natural Language Processing is a branch of Artificial Intelligence.
#
# 2. It helps computers understand human language.
#
# 3. NLTK and spaCy are popular NLP libraries.
#
# Word Tokenization:
# ...
